# %% [markdown]
# <a href="https://colab.research.google.com/github/maulikk3/OR-CODE-GENERATOR/blob/main/QR_code_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyqrcode pypng
# Out:
# Collecting pyqrcode
#   Downloading PyQRCode-1.2.1.zip (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pypng
#   Downloading pypng-0.20220715.0-py3-none-any.whl.metadata (13 kB)
# Downloading pypng-0.20220715.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 4.1 MB/s eta 0:00:00
# Building wheels for collected packages: pyqrcode
#   Building wheel for pyqrcode (setup.py) ... done
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36222 sha256=9317c9e323c42d0855ad650b55d9a18b77fae9722346303715a2b71e85fe88a3
#   Stored in directory: /root/.cache/pip/wheels/f5/db/22/ade11e0c0854d1bb2fcc673dc90f6495ee2c0d2b6eb41492e3
# Successfully built pyqrcode
# Installing collected packages: pyqrcode, pypng
# Successfully installed pypng-0.20220715.0 pyqrcode-1.2.1

# %%
'''
Python Program to Generate QR Code
'''

# Import the necessary module!
import pyqrcode

# Define the data:
# We need some text that we want to convert as our QR Code.
data = "https://www.linkedin.com/in/maulik-kumar-72347b323/"

# Create qrcode:
qr = pyqrcode.create(data)

# Now let's store it in .png format with proper scaling.
qr.png("QR.png", scale= 5)
